# %%
import pandas_datareader
import pandas as pd 
import numpy as np

# %%
df_tsla = pandas_datareader.get_data_yahoo("TSLA")

# %%
df_tsla.shape
# Out:
# (1260, 6)

# %%
df_tsla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0  49.245998
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999

# %%
### STRAIGHT UP PLOTTING
df_tsla["High"].plot(figsize = (12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlim anad y lim
df_tsla["High"].plot(xlim = ["2020-01-01" , "2021-09-01"],ylim = [0,1000],figsize = (12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## xlim anad y lim and color
df_tsla["High"].plot(c = "red",xlim = ["2020-01-01" , "2021-09-01"],ylim = [0,1000],figsize = (12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tsla.index
# Out:
# DatetimeIndex(['2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10',
#                ...
#                '2022-02-11', '2022-02-14', '2022-02-15', '2022-02-16',
#                '2022-02-17', '2022-02-18', '2022-02-22', '2022-02-23',
#                '2022-02-24', '2022-02-25'],
#               dtype='datetime64[ns]', name='Date', length=1260, freq=None)

# %%
index = df_tsla.loc["2020-01-01" : "2021 -09-01"].index

# %%
opentsla = df_tsla.loc["2020-01-01" : "2021 -09-01"]["Open"]

# %%
opentsla
# Out:
# Date
# 2020-01-02     84.900002
# 2020-01-03     88.099998
# 2020-01-06     88.094002
# 2020-01-07     92.279999
# 2020-01-08     94.739998
#                  ...
# 2021-08-26    708.309998
# 2021-08-27    705.000000
# 2021-08-30    714.719971
# 2021-08-31    733.000000
# 2021-09-01    734.080017
# Name: Open, Length: 421, dtype: float64

# %%
### VIZ AND SUBPLOT
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig , axis = plt.subplots()
plt.tight_layout()
fig.autofmt_xdate()
axis.plot(index,opentsla , c= "green")

# %%
## DATE TIME INDEX
df_tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   datetime64[ns]
#  1   High       1260 non-null   float64
#  2   Low        1260 non-null   float64
#  3   Open       1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Volume     1260 non-null   float64
#  6   Adj Close  1260 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
df_tsla
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 0    2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 1    2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2    2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 3    2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 4    2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...         ...         ...         ...         ...         ...         ...
# 1255 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 1256 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 1257 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 1258 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 1259 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#        Adj Close
# 0      49.245998
# 1      49.998001
# ...

# %%
df_tsla.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0
# 1 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0
# 2 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0
# 3 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0
# 4 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0
#
#    Adj Close
# 0  49.245998
# 1  49.998001
# 2  50.004002
# 3  50.096001
# 4  50.313999

# %%
df_tsla
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 0    2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 1    2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2    2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 3    2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 4    2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...         ...         ...         ...         ...         ...         ...
# 1255 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 1256 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 1257 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 1258 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 1259 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#        Adj Close
# 0      49.245998
# 1      49.998001
# ...

# %%
##datetime
from datetime import datetime

# %%
datetime(2022,2,22)
# Out:
# datetime.datetime(2022, 2, 22, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 2, 27, 11, 59, 48, 125732)

# %%
### TIME RESAMPLING

# %%
df_tsla.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0
# 1 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0
# 2 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0
# 3 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0
# 4 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0
#
#    Adj Close
# 0  49.245998
# 1  49.998001
# 2  50.004002
# 3  50.096001
# 4  50.313999

# %%
df_tsla.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0
# 1 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0
# 2 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0
# 3 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0
# 4 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0
#
#    Adj Close
# 0  49.245998
# 1  49.998001
# 2  50.004002
# 3  50.096001
# 4  50.313999

# %%
df_tsla["High"].rolling(10).mean().head(50)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     50.2042
# 10    50.1740
# 11    50.3164
# 12    50.4394
# 13    50.6888
# 14    50.9574
# 15    51.2144
# 16    51.4326
# 17    51.5326
# 18    51.7128
# 19    52.0606
# 20    52.5350
# 21    52.9862
# 22    53.3582
# 23    53.6832
# 24    53.9702
# 25    54.6592
# 26    55.4594
# 27    56.4556
# 28    57.3410
# 29    58.1170
# 30    58.9802
# 31    59.6360
# 32    60.2130
# 33    60.7208
# 34    61.2072
# 35    61.2440
# 36    61.2802
# 37    61.3656
# 38    61.4548
# 39    61.6120
# 40    61.6170
# 41    61.6376
# 42    61.7304
# 43    61.8786
# 44    62.3436
# 45    62.8800
# 46    63.1782
# 47    63.1506
# 48    63.1936
# 49    63.2584
# Name: High, dtype: float64

# %%
df_tsla["Open:30 days rolling"] =  df_tsla["Open"].rolling(30).mean()

# %%
df_tsla.head(50)
# Out:
#          Date       High        Low       Open      Close      Volume  \
# 0  2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0
# 1  2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0
# 2  2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0
# 3  2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0
# 4  2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0
# 5  2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0
# 6  2017-03-07  50.778000  49.664001  50.383999  49.717999  17297500.0
# 7  2017-03-08  50.014000  49.063999  49.400002  49.374001  18626000.0
# 8  2017-03-09  49.731998  48.599998  49.526001  48.980000  19396500.0
# 9  2017-03-10  49.299999  48.599998  49.242001  48.737999  15331500.0
# 10 2017-03-13  49.369999  48.556000  48.964001  49.234001  15113000.0
# 11 2017-03-14  51.624001  49.203999  49.222000  51.599998  37992000.0
# ...

# %%
##smoothening
df_tsla[["Open" , "Open:30 days rolling"]].plot(figsize = (12,5))
# Out:
# <AxesSubplot:>

# %%
# ### ASSIGNMENT
# 1 . GET MICROSOFT DATA 
# 2 . GET MAX STOCK PRICE FROM 2017 -2022
# 3 . which is the date of the highest price of stock and lowest price

# %%
df_mc =
